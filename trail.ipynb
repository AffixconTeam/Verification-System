# %%
import toml
config = toml.load("config.toml")
config
# Out:
# {'database': {'user': 'Affix Team',
#   'password': 'IDnoCoUC!jem2N',
#   'account': 'FQDYHCR.DV79350',
#   'warehouse': 'COMPUTE_WH',
#   'database': 'KYC',
#   'schema': ' SHARED_DATA',
#   'role': 'ACCOUNTADMIN'}}

# %%
from template import conn
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\Users\tuan.seedin\Desktop\Developments\KYC\KYC-Verification\Snowflakes\FASTAPI\Verification-System\api\Lib\site-packages\snowflake\connector\connection.py:1414, in SnowflakeConnection._authenticate(self, auth_instance)
#    1413 try:
# -> 1414     auth.authenticate(
#    1415         auth_instance=auth_instance,
#    1416         account=self.account,
#    1417         user=self.user,
#    1418         database=self.database,
#    1419         schema=self.schema,
#    1420         warehouse=self.warehouse,
#    1421         role=self.role,
#    1422         passcode=self._passcode,
#    1423         passcode_in_password=self._passcode_in_password,
#    1424         mfa_callback=self._mfa_callback,
#    1425         password_callback=self._password_callback,
#    1426         session_parameters=self._session_parameters,
# ...

# %%
{'database': {'user': 'Affix Team',
  'password': 'IDnoCoUC!jem2N',
  'account': 'FQDYHCR.DV79350',
  'warehouse': 'COMPUTE_WH',
  'database': 'KYC',
  'schema': ' SHARED_DATA',
  'role': 'ACCOUNTADMIN'}}

# %%
import snowflake.connector

config = toml.load("config.toml")["snowflake"]
conn = snowflake.connector.connect(**config)

# %%
import snowflake.connector

# Establish connection
conn = snowflake.connector.connect(
    user=config['database']['user'],
    password=config['database']['password'],
    account=config['database']['account'],
    warehouse=config['database']['warehouse'],
    database=config['database']['database'],
    schema=config['database']['schema'].strip(),
)

# Create a cursor object
cursor = conn.cursor()

# Execute a query
cursor.execute("SELECT CURRENT_DATE;")

# Fetch the result
result = cursor.fetchone()
print(f"Today's date: {result[0]}")

# Close the connection
cursor.close()
conn.close()
# Out:
# d:\Users\tuan.seedin\Desktop\Developments\KYC\KYC-Verification\Snowflakes\FASTAPI\Verification-System\api\Lib\site-packages\snowflake\connector\config_manager.py:351: UserWarning: Bad owner or permissions on D:\Users\tuan.seedin\.snowflake\connections.toml
#   warn(f"Bad owner or permissions on {str(filep)}{chmod_message}")
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\Users\tuan.seedin\Desktop\Developments\KYC\KYC-Verification\Snowflakes\FASTAPI\Verification-System\api\Lib\site-packages\snowflake\connector\connection.py:1414, in SnowflakeConnection._authenticate(self, auth_instance)
#    1413 try:
# -> 1414     auth.authenticate(
#    1415         auth_instance=auth_instance,
#    1416         account=self.account,
#    1417         user=self.user,
#    1418         database=self.database,
#    1419         schema=self.schema,
# ...
